# %% [markdown]
# # Social Good Hackathon - Covid19 and Texas Counties

# %% [markdown]
# # Data Prep Part 1

# %% [markdown]
# #### Files used (11)
# 2020 Texas County Health.csv
# Age_final.csv
# education_unemployment_final.csv
# ethnicity_race_final.csv
# new policitcal demographics_final.csv
# Texas Nursing Facility.csv
# texas prisons.csv
# TX hospital beds.csv
# TX military installations.csv
# TxDOT_Roadway_Inventory.txt
# Texas detail age.csv
# Texas_county_numbers.csv

# %%
import pandas as pd

# %%
import sagemaker.amazon.common as smac
import sagemaker
from sagemaker import get_execution_role

# %%
role = get_execution_role()
input_bucket = 'texas-counties-covid19'

# %% [markdown]
# ## First set of features

# %%
# dataset originally downloaded from:  https://imis.county.org/iMIS/CountyInformationProgram/QueriesCIP.aspx
in_data_key = 'Age_final.csv'
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
age = pd.read_csv(data_location)

# %%
# dataset originally downloaded from:  https://imis.county.org/iMIS/CountyInformationProgram/QueriesCIP.aspx
in_data_key = "education_unemployment_final.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
edu = pd.read_csv(data_location)

# %%
# dataset originally downloaded from:  https://imis.county.org/iMIS/CountyInformationProgram/QueriesCIP.aspx
in_data_key = "ethnicity_race_final.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
race = pd.read_csv(data_location)

# %%
# dataset originally downloaded from:  https://imis.county.org/iMIS/CountyInformationProgram/QueriesCIP.aspx
in_data_key = "new policitcal demographics_final.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
poli = pd.read_csv(data_location)

# %%
# dataset originally downloaded from:  
# https://www.txdot.gov/inside-txdot/division/transportation-planning/roadway-inventory.html
in_data_key="TxDOT_Roadway_Inventory.txt"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
roads = pd.read_csv(data_location, sep="|", usecols=[30, 208, 209, 210, 211])
roads.head()
# Out:
#    CO  LEN_SEC  LN_MILES      DVMT  DTRKVMT
# 0  15    0.416     0.416   401.024    0.000
# 1  15    0.123     0.123  1043.532   40.713
# 2  15    0.006     0.006    50.904    1.986
# 3  15    0.279     0.279  2367.036   92.349
# 4  15    0.326     0.326  3871.902    0.000

# %%
# selection pertinent features from the larger roads dataset
#small_roads = roads.iloc[:, [30, 208, 209, 210, 211]]
small_roads = roads.copy()

# %%
roads_by_county = small_roads.groupby("CO").sum()

# %%
roads_by_county.reset_index(inplace=True)

# %%
roads_by_county
# Out:
#       CO   LEN_SEC  LN_MILES         DVMT     DTRKVMT
# 0      1  1563.054  3241.985  1771161.086  217583.748
# 1      2   681.348  1440.703  1817432.214  340429.090
# 2      3  1522.123  3226.201  4012089.437  747829.119
# 3      4   465.179   916.157   937527.224   79097.644
# 4      5   782.152  1608.504   604312.790  110647.681
# ..   ...       ...       ...          ...         ...
# 249  250  1341.465  2756.760  1246402.933  120880.396
# 250  251   750.011  1515.201   402569.649   55363.059
# 251  252  1011.298  2041.825   486813.968   56522.578
# 252  253   299.189   634.108   369961.028   54823.312
# 253  254   476.516   966.964   427754.100   82825.740
#
# [254 rows x 5 columns]

# %%
# the df translates the county numbers used in roads_by_county df to county names
in_data_key = "Texas_county_numbers.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
co_num = pd.read_csv(data_location)

# %%
roads_names = roads_by_county.merge(co_num, how="left", on="CO")
roads_names.drop("CO", axis=1, inplace=True)
roads_names
# Out:
#       LEN_SEC  LN_MILES         DVMT     DTRKVMT    County
# 0    1563.054  3241.985  1771161.086  217583.748  Anderson
# 1     681.348  1440.703  1817432.214  340429.090   Andrews
# 2    1522.123  3226.201  4012089.437  747829.119  Angelina
# 3     465.179   916.157   937527.224   79097.644   Aransas
# 4     782.152  1608.504   604312.790  110647.681    Archer
# ..        ...       ...          ...         ...       ...
# 250  1341.465  2756.760  1246402.933  120880.396      Wood
# 251   750.011  1515.201   402569.649   55363.059    Yoakum
# 252  1011.298  2041.825   486813.968   56522.578     Young
# 253   299.189   634.108   369961.028   54823.312    Zapata
# 254   476.516   966.964   427754.100   82825.740    Zavala
#
# [255 rows x 5 columns]

# %%
age.head()
# Out:
#      County  Median Age  % Age 17 and Under  % Age 65 and Older  \
# 0  Anderson        39.1               19.58               14.54
# 1   Andrews        31.8               30.90               10.53
# 2  Angelina        37.1               25.81               15.79
# 3   Aransas        49.3               18.73               27.30
# 4    Archer        44.3               21.77               19.89
#
#    % Age 85 and Older
# 0                1.48
# 1                1.37
# 2                1.94
# 3                2.62
# 4                2.17

# %%
edu.head()
# Out:
#      County  % High School Graduate or Higher  % Bachelor s Degree or Higher  \
# 0  Anderson                              80.2                           11.8
# 1   Andrews                              73.8                           10.6
# 2  Angelina                              79.9                           15.7
# 3   Aransas                              83.2                           20.2
# 4    Archer                              90.1                           21.8
#
#    Unemployment Rate (%)
# 0                    3.6
# 1                    3.1
# 2                    5.1
# 3                    6.8
# 4                    3.4

# %%
race.head()
# Out:
#      County  Ethnicity: % Hispanic  Race: % White Alone  \
# 0  Anderson                  17.82                75.11
# 1   Andrews                  56.19                94.22
# 2  Angelina                  22.18                81.27
# 3   Aransas                  27.66                93.05
# 4    Archer                   8.68                95.58
#
#    Race: % African American Alone  \
# 0                           21.49
# 1                            1.94
# 2                           15.44
# 3                            1.79
# 4                            1.03
#
#    Race: % American Indian & Alaska Native Alone  Race: % Asian Alone  \
# 0                                           0.68                 0.90
# 1                                           1.47                 0.75
# 2                                           0.75                 1.17
# 3                                           1.24                 1.93
# 4                                           1.42                 0.43
#
#    Race: % Native Hawaiian and Other Pacific Islander Alone  \
# 0                                               0.14
# 1                                               0.02
# 2                                               0.06
# 3                                               0.08
# 4                                               0.03
#
#    Race: % Multi-Racial
# 0                  1.67
# 1                  1.61
# 2                  1.31
# 3                  1.90
# 4                  1.50

# %%
poli.head()
# Out:
#      County  Votes  Percent_Voted  Republicans 2016  Democrats 2016  \
# 0  Anderson  16887       0.293605         77.959377       19.885119
# 1   Andrews   4926       0.350855         79.679253       16.971173
# 2  Angelina  29870       0.352998         72.534315       25.236023
# 3   Aransas  10467       0.439273         73.851151       23.483329
# 4    Archer   4269       0.474597         88.662450        9.229328
#
#    Green 2016  Libertarians 2016  \
# 0    0.337538           1.817966
# 1    0.365408           2.984166
# 2    0.354871           1.874791
# 3    0.391707           2.273813
# 4    0.234247           1.873975
#
#    Preschool.Enrollment.Ratio.enrolled.ages.3.and.4  Gini.Coefficient  \
# 0                                              35.9             0.465
# 1                                              38.4             0.531
# 2                                              51.3             0.452
# 3                                              67.9             0.470
# 4                                              62.9             0.409
#
#    Management.professional.and.related.occupations  ...  Violent.crime  \
# 0                                            23.60  ...         311.56
# 1                                            20.90  ...         536.37
# 2                                            27.75  ...         350.84
# 3                                            31.05  ...         186.09
# 4                                            28.20  ...         112.93
#
#    Injury.deaths        CA         S       MAR       CFS      ACFS  Mean Alc  \
# 0           93.1  0.229051 -0.948391  0.711662  0.000005  0.000005  0.000074
# 1           79.8  0.827519 -1.081741  0.821886  0.000045  0.000045  0.000109
# 2           65.2  0.620367 -0.793494  0.479538  0.000029  0.000029  0.000060
# 3          102.4 -0.093289 -0.794147  0.733924  0.000044  0.000044  0.000089
# 4           59.6  1.421798  0.230079  0.547123  0.000008  0.000008  0.000081
#
#     Max Alc  Mixedness
# 0  0.000423  -0.470898
# 1  0.000622  -0.052599
# 2  0.000468  -0.681732
# 3  0.000353  -0.216679
# 4  0.000426  -0.653378
#
# [5 rows x 32 columns]

# %%
# merging all the datasets together 
final_df = age.merge(edu, how="left", on="County")

# %%
final_df = final_df.merge(race, how="left", on="County")

# %%
final_df = final_df.merge(poli, how="left", on="County")

# %%
final_df = final_df.merge(roads_names, how="left", on="County")

# %%
final_df
# Out:
#        County  Median Age  % Age 17 and Under  % Age 65 and Older  \
# 0    Anderson        39.1               19.58               14.54
# 1     Andrews        31.8               30.90               10.53
# 2    Angelina        37.1               25.81               15.79
# 3     Aransas        49.3               18.73               27.30
# 4      Archer        44.3               21.77               19.89
# ..        ...         ...                 ...                 ...
# 249      Wood        48.7               19.34               27.10
# 250    Yoakum        30.8               33.03               11.67
# 251     Young        41.4               24.14               20.01
# 252    Zapata        29.7               33.29               12.57
# 253    Zavala        31.1               29.32               14.05
#
#      % Age 85 and Older  % High School Graduate or Higher  \
# 0                  1.48                              80.2
# 1                  1.37                              73.8
# 2                  1.94                              79.9
# 3                  2.62                              83.2
# 4                  2.17                              90.1
# ..                  ...                               ...
# 249                2.82                              85.1
# 250                1.31                              71.4
# 251                2.69                              81.6
# 252                1.39                              50.3
# 253                1.96                              59.2
#
#      % Bachelor s Degree or Higher  Unemployment Rate (%)  \
# 0                             11.8                    3.6
# 1                             10.6                    3.1
# 2                             15.7                    5.1
# 3                             20.2                    6.8
# 4                             21.8                    3.4
# ..                             ...                    ...
# 249                           17.1                    4.7
# 250                           17.8                    3.5
# 251                           18.6                    3.8
# 252                            8.3                    7.3
# 253                            9.1                   11.1
#
#      Ethnicity: % Hispanic  Race: % White Alone  ...       MAR       CFS  \
# 0                    17.82                75.11  ...  0.711662  0.000005
# 1                    56.19                94.22  ...  0.821886  0.000045
# 2                    22.18                81.27  ...  0.479538  0.000029
# 3                    27.66                93.05  ...  0.733924  0.000044
# 4                     8.68                95.58  ...  0.547123  0.000008
# ..                     ...                  ...  ...       ...       ...
# 249                  10.07                91.42  ...  0.690706  0.000039
# 250                  66.57                95.05  ...  1.018043  0.000112
# 251                  18.95                95.17  ...  0.878403  0.000042
# 252                  94.44                98.55  ...  1.810431  0.000210
# 253                  93.94                96.74  ...  1.292618 -0.000153
#
#          ACFS  Mean Alc   Max Alc  Mixedness   LEN_SEC  LN_MILES         DVMT  \
# 0    0.000005  0.000074  0.000423  -0.470898  1563.054  3241.985  1771161.086
# 1    0.000045  0.000109  0.000622  -0.052599   681.348  1440.703  1817432.214
# 2    0.000029  0.000060  0.000468  -0.681732  1522.123  3226.201  4012089.437
# 3    0.000044  0.000089  0.000353  -0.216679   465.179   916.157   937527.224
# 4    0.000008  0.000081  0.000426  -0.653378   782.152  1608.504   604312.790
# ..        ...       ...       ...        ...       ...       ...          ...
# 249  0.000039  0.000041  0.000152  -0.402126  1341.465  2756.760  1246402.933
# 250  0.000112  0.000159  0.000614   0.652742   750.011  1515.201   402569.649
# 251  0.000042  0.000073  0.000268  -0.073630  1011.298  2041.825   486813.968
# 252  0.000210  0.000641  0.001929   3.248312   299.189   634.108   369961.028
# 253  0.000153  0.000700  0.002437   2.431733   476.516   966.964   427754.100
#
#         DTRKVMT
# 0    217583.748
# 1    340429.090
# 2    747829.119
# 3     79097.644
# 4    110647.681
# ..          ...
# 249  120880.396
# 250   55363.059
# 251   56522.578
# 252   54823.312
# 253   82825.740
#
# [254 rows x 50 columns]

# %%
# examining the final_df for null values
final_df.isna().sum()
# Out:
# County                                                         0
# Median Age                                                     0
# % Age 17 and Under                                             0
# % Age 65 and Older                                             0
# % Age 85 and Older                                             0
# % High School Graduate or Higher                               0
# % Bachelor s Degree or Higher                                  0
# Unemployment Rate (%)                                          0
# Ethnicity: % Hispanic                                          0
# Race: % White Alone                                            0
# Race: % African American Alone                                 0
# Race: % American Indian & Alaska Native Alone                  0
# Race: % Asian Alone                                            0
# Race: % Native Hawaiian and Other Pacific Islander Alone       0
# Race: % Multi-Racial                                           0
# Votes                                                          2
# Percent_Voted                                                  2
# Republicans 2016                                               2
# Democrats 2016                                                 2
# Green 2016                                                     2
# Libertarians 2016                                              2
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4               6
# Gini.Coefficient                                               2
# Management.professional.and.related.occupations                2
# Service.occupations                                            2
# Sales.and.office.occupations                                   2
# Farming.fishing.and.forestry.occupations                       2
# Construction.extraction.maintenance.and.repair.occupations     2
# Production.transportation.and.material.moving.occupations      2
# Low.birthweight                                               30
# Teen.births                                                   13
# Children.in.single.parent.households                           3
# Adult.obesity                                                  2
# Diabetes                                                       2
# Sexually.transmitted.infections                               22
# Uninsured                                                      2
# Violent.crime                                                  3
# Injury.deaths                                                 53
# CA                                                             3
# S                                                              6
# MAR                                                            6
# CFS                                                            6
# ACFS                                                           6
# Mean Alc                                                       6
# Max Alc                                                        6
# Mixedness                                                      6
# LEN_SEC                                                        2
# LN_MILES                                                       2
# DVMT                                                           2
# DTRKVMT                                                        2
# dtype: int64

# %%
# fill in all nulls with the median of the column 
#final_df_fillna = final_df.iloc[:, 1:].apply(lambda col: col.fillna(col.median()), axis=0)

# %%
final_df_fillna["County"] = final_df["County"]

# %%
final_df_fillna.isna().sum()
# Out:
# Median Age                                                    0
# % Age 17 and Under                                            0
# % Age 65 and Older                                            0
# % Age 85 and Older                                            0
# % High School Graduate or Higher                              0
# % Bachelor s Degree or Higher                                 0
# Unemployment Rate (%)                                         0
# Ethnicity: % Hispanic                                         0
# Race: % White Alone                                           0
# Race: % African American Alone                                0
# Race: % American Indian & Alaska Native Alone                 0
# Race: % Asian Alone                                           0
# Race: % Native Hawaiian and Other Pacific Islander Alone      0
# Race: % Multi-Racial                                          0
# Votes                                                         0
# Percent_Voted                                                 0
# Republicans 2016                                              0
# Democrats 2016                                                0
# Green 2016                                                    0
# Libertarians 2016                                             0
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4              0
# Gini.Coefficient                                              0
# Management.professional.and.related.occupations               0
# Service.occupations                                           0
# Sales.and.office.occupations                                  0
# Farming.fishing.and.forestry.occupations                      0
# Construction.extraction.maintenance.and.repair.occupations    0
# Production.transportation.and.material.moving.occupations     0
# Low.birthweight                                               0
# Teen.births                                                   0
# Children.in.single.parent.households                          0
# Adult.obesity                                                 0
# Diabetes                                                      0
# Sexually.transmitted.infections                               0
# Uninsured                                                     0
# Violent.crime                                                 0
# Injury.deaths                                                 0
# CA                                                            0
# S                                                             0
# MAR                                                           0
# CFS                                                           0
# ACFS                                                          0
# Mean Alc                                                      0
# Max Alc                                                       0
# Mixedness                                                     0
# LEN_SEC                                                       0
# LN_MILES                                                      0
# DVMT                                                          0
# DTRKVMT                                                       0
# County                                                        0
# dtype: int64

# %%
final_df_fillna
# Out:
#      Median Age  % Age 17 and Under  % Age 65 and Older  % Age 85 and Older  \
# 0          39.1               19.58               14.54                1.48
# 1          31.8               30.90               10.53                1.37
# 2          37.1               25.81               15.79                1.94
# 3          49.3               18.73               27.30                2.62
# 4          44.3               21.77               19.89                2.17
# ..          ...                 ...                 ...                 ...
# 249        48.7               19.34               27.10                2.82
# 250        30.8               33.03               11.67                1.31
# 251        41.4               24.14               20.01                2.69
# 252        29.7               33.29               12.57                1.39
# 253        31.1               29.32               14.05                1.96
#
#      % High School Graduate or Higher  % Bachelor s Degree or Higher  \
# 0                                80.2                           11.8
# 1                                73.8                           10.6
# 2                                79.9                           15.7
# 3                                83.2                           20.2
# 4                                90.1                           21.8
# ..                                ...                            ...
# 249                              85.1                           17.1
# 250                              71.4                           17.8
# 251                              81.6                           18.6
# 252                              50.3                            8.3
# 253                              59.2                            9.1
#
#      Unemployment Rate (%)  Ethnicity: % Hispanic  Race: % White Alone  \
# 0                      3.6                  17.82                75.11
# 1                      3.1                  56.19                94.22
# 2                      5.1                  22.18                81.27
# 3                      6.8                  27.66                93.05
# 4                      3.4                   8.68                95.58
# ..                     ...                    ...                  ...
# 249                    4.7                  10.07                91.42
# 250                    3.5                  66.57                95.05
# 251                    3.8                  18.95                95.17
# 252                    7.3                  94.44                98.55
# 253                   11.1                  93.94                96.74
#
#      Race: % African American Alone  ...       CFS      ACFS  Mean Alc  \
# 0                             21.49  ...  0.000005  0.000005  0.000074
# 1                              1.94  ...  0.000045  0.000045  0.000109
# 2                             15.44  ...  0.000029  0.000029  0.000060
# 3                              1.79  ...  0.000044  0.000044  0.000089
# 4                              1.03  ...  0.000008  0.000008  0.000081
# ..                              ...  ...       ...       ...       ...
# 249                            5.41  ...  0.000039  0.000039  0.000041
# 250                            1.41  ...  0.000112  0.000112  0.000159
# 251                            1.52  ...  0.000042  0.000042  0.000073
# 252                            0.38  ...  0.000210  0.000210  0.000641
# 253                            1.20  ... -0.000153  0.000153  0.000700
#
#       Max Alc  Mixedness   LEN_SEC  LN_MILES         DVMT     DTRKVMT  \
# 0    0.000423  -0.470898  1563.054  3241.985  1771161.086  217583.748
# 1    0.000622  -0.052599   681.348  1440.703  1817432.214  340429.090
# 2    0.000468  -0.681732  1522.123  3226.201  4012089.437  747829.119
# 3    0.000353  -0.216679   465.179   916.157   937527.224   79097.644
# 4    0.000426  -0.653378   782.152  1608.504   604312.790  110647.681
# ..        ...        ...       ...       ...          ...         ...
# 249  0.000152  -0.402126  1341.465  2756.760  1246402.933  120880.396
# 250  0.000614   0.652742   750.011  1515.201   402569.649   55363.059
# 251  0.000268  -0.073630  1011.298  2041.825   486813.968   56522.578
# 252  0.001929   3.248312   299.189   634.108   369961.028   54823.312
# 253  0.002437   2.431733   476.516   966.964   427754.100   82825.740
#
#        County
# 0    Anderson
# 1     Andrews
# 2    Angelina
# 3     Aransas
# 4      Archer
# ..        ...
# 249      Wood
# 250    Yoakum
# 251     Young
# 252    Zapata
# 253    Zavala
#
# [254 rows x 50 columns]

# %% [markdown]
# ## Second set of features

# %%
# dataset originally downloaded from: https://data.medicare.gov/Nursing-Home-Compare/Provider-Info/4pq5-n9py
in_data_key = "Texas Nursing Facility.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
nursing_homes = pd.read_csv(data_location)

# %%
nursing_homes.head()
# Out:
#      county  nursing home capacity
# 0  ANDERSON                     98
# 1  ANDERSON                    120
# 2  ANDERSON                    199
# 3  ANDERSON                    102
# 4  ANDERSON                    120

# %%
nh_df = nursing_homes.groupby("county").sum().reset_index()
nh_df.head()
# Out:
#      county  nursing home capacity
# 0  ANDERSON                    639
# 1   ANDREWS                     90
# 2  ANGELINA                    920
# 3   ARANSAS                    212
# 4    ARCHER                     46

# %%
nh_df["county"] = nh_df["county"].apply(lambda x: x.title())

# %%
nh_df.head()
# Out:
#      county  nursing home capacity
# 0  Anderson                    639
# 1   Andrews                     90
# 2  Angelina                    920
# 3   Aransas                    212
# 4    Archer                     46

# %%
# dataset originally downloaded from: https://texasalmanac.com/topics/government/texas-prisons
in_data_key = "texas prisons.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
prisons = pd.read_csv(data_location)

# %%
prisons.head()
# Out:
#      county max capacity (gender) employees
# 0  Anderson            3,471 Male       633
# 1  Anderson            4,139 Male       879
# 2  Anderson            2,128 Male       437
# 3  Anderson            3,800 Male       816
# 4  Anderson            1,137 Male       290

# %%
prisons["capacity"] = prisons["max capacity (gender)"].apply(lambda x: x.split()[0].replace(',', ''))
prisons["employees"] = prisons["employees"].apply(lambda x: x.replace(',', ''))
prisons.head()
# Out:
#      county max capacity (gender) employees capacity
# 0  Anderson            3,471 Male       633     3471
# 1  Anderson            4,139 Male       879     4139
# 2  Anderson            2,128 Male       437     2128
# 3  Anderson            3,800 Male       816     3800
# 4  Anderson            1,137 Male       290     1137

# %%
prisons.iloc[:, 2:4] = prisons.iloc[:, 2:4].apply(lambda x: x.astype('int64'))
prisons["prison capacity and jail employees"] = prisons["employees"] + prisons["capacity"]

# %%
prisons.drop(columns=["max capacity (gender)", "employees", "capacity"], axis=1, inplace=True)

# %%
prisons.head()
# Out:
#      county prison capacity and jail employees
# 0  Anderson                               4104
# 1  Anderson                               5018
# 2  Anderson                               2565
# 3  Anderson                               4616
# 4  Anderson                               1427

# %%
prisons_df = prisons.groupby("county").sum()
prisons_df.head()
# Out:
#           prison capacity and jail employees
# county
# Anderson                               17730
# Angelina                                1399
# Bee                                     9021
# Bexar                                   2658
# Bowie                                   3578

# %%
# dataset originally downloaded from: https://texasalmanac.com/topics/government/major-military-installations
in_data_key = "TX military installations.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
military = pd.read_csv(data_location)
military.head()
# Out:
#     county  military installation
# 0   Nueces                      1
# 1  Tarrant                      1
# 2  Kleberg                      1
# 3  El Paso                      1
# 4    Bell                       1

# %%
military.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 11 non-null     object
#  1   military installation  11 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 304.0+ bytes

# %%
# dataset originally downloaded from:  https://hifld-geoplatform.opendata.arcgis.com/datasets/6ac5e325468c4cb9b905f1728d6fbf0f_0
in_data_key = "TX hospital beds.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
hos_beds = pd.read_csv(data_location)

# %%
hos_beds.head()
# Out:
#      county  hospital beds
# 0  ANDERSON             86
# 1  ANDERSON             70
# 2   ANDREWS             34
# 3  ANGELINA            149
# 4  ANGELINA             24

# %%
hos_beds_df = hos_beds.groupby(["county"]).sum().reset_index()
hos_beds_df["county"] = hos_beds_df["county"].apply(lambda x: x.title())
hos_beds_df.head()
# Out:
#      county  hospital beds
# 0  Anderson            156
# 1   Andrews             34
# 2  Angelina            470
# 3  Atascosa             67
# 4    Austin             32

# %%
# dataset originally downloaded from:  https://demographics.texas.gov/Download/Estimates?fid=b6b495fa6c904a318b184d21eedf860b)
in_data_key = "Texas detail age.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
detail_age = pd.read_csv(data_location)
detail_age.head()
# Out:
#      county Age range population
# 0  Anderson      < 10      5,816
# 1  Anderson    19-Oct      6,633
# 2  Anderson     20-29      8,198
# 3  Anderson     30-39      9,904
# 4  Anderson     40-49      8,920

# %%
detail_age_df = detail_age.groupby('county')['population'].apply(lambda df: df.reset_index(drop=True)).unstack().reset_index()
detail_age_df.head()
# Out:
#      county       0       1       2       3       4       5      6      7  \
# 0  Anderson   5,816   6,633   8,198   9,904   8,920   7,433  5,980  3,963
# 1   Andrews   3,169   3,044   2,912   2,863   2,088   1,912  1,431    753
# 2  Angelina  12,714  13,386  12,292  11,347  10,915  11,311  9,583  6,451
# 3   Aransas   2,416   2,431   2,646   2,507   2,321   3,093  3,696  3,149
# 4    Archer   1,008   1,180   1,176     984   1,094   1,383  1,325    814
#
#        8    9
# 0  1,775  357
# 1    414   92
# 2  3,028  660
# 3  1,243  222
# 4    423   72

# %%
detail_age_df.rename(columns={0: "% lt_10", 1: "% 10_19", 2: "% 20_29", 3: "% 30_39", 4: "% 40_49", 5: "% 50-59", 6: "% 60_69", 7: "% 70_79", 8: "% 80_89", 9: "% over_90"}, inplace=True)
detail_age_df.head()
# Out:
#      county % lt_10 % 10_19 % 20_29 % 30_39 % 40_49 % 50-59 % 60_69 % 70_79  \
# 0  Anderson   5,816   6,633   8,198   9,904   8,920   7,433   5,980   3,963
# 1   Andrews   3,169   3,044   2,912   2,863   2,088   1,912   1,431     753
# 2  Angelina  12,714  13,386  12,292  11,347  10,915  11,311   9,583   6,451
# 3   Aransas   2,416   2,431   2,646   2,507   2,321   3,093   3,696   3,149
# 4    Archer   1,008   1,180   1,176     984   1,094   1,383   1,325     814
#
#   % 80_89 % over_90
# 0   1,775       357
# 1     414        92
# 2   3,028       660
# 3   1,243       222
# 4     423        72

# %%
detail_age_df = detail_age_df.applymap(lambda x: x.replace(",", ''))
detail_age_df.head()
# Out:
#      county % lt_10 % 10_19 % 20_29 % 30_39 % 40_49 % 50-59 % 60_69 % 70_79  \
# 0  Anderson    5816    6633    8198    9904    8920    7433    5980    3963
# 1   Andrews    3169    3044    2912    2863    2088    1912    1431     753
# 2  Angelina   12714   13386   12292   11347   10915   11311    9583    6451
# 3   Aransas    2416    2431    2646    2507    2321    3093    3696    3149
# 4    Archer    1008    1180    1176     984    1094    1383    1325     814
#
#   % 80_89 % over_90
# 0    1775       357
# 1     414        92
# 2    3028       660
# 3    1243       222
# 4     423        72

# %%
detail_age_df.iloc[:, 1:11] = detail_age_df.iloc[:, 1:11].apply(lambda x: x.astype('int64'))
detail_age_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   county     254 non-null    object
#  1   % lt_10    254 non-null    object
#  2   % 10_19    254 non-null    object
#  3   % 20_29    254 non-null    object
#  4   % 30_39    254 non-null    object
#  5   % 40_49    254 non-null    object
#  6   % 50-59    254 non-null    object
#  7   % 60_69    254 non-null    object
#  8   % 70_79    254 non-null    object
#  9   % 80_89    254 non-null    object
#  10  % over_90  254 non-null    object
# dtypes: object(11)
# memory usage: 22.0+ KB

# %%
detail_age_df["Population_total"] = detail_age_df.iloc[:, 1:11].sum(axis=1)
detail_age_df.head()
# Out:
#      county % lt_10 % 10_19 % 20_29 % 30_39 % 40_49 % 50-59 % 60_69 % 70_79  \
# 0  Anderson    5816    6633    8198    9904    8920    7433    5980    3963
# 1   Andrews    3169    3044    2912    2863    2088    1912    1431     753
# 2  Angelina   12714   13386   12292   11347   10915   11311    9583    6451
# 3   Aransas    2416    2431    2646    2507    2321    3093    3696    3149
# 4    Archer    1008    1180    1176     984    1094    1383    1325     814
#
#   % 80_89 % over_90  Population_total
# 0    1775       357           58979.0
# 1     414        92           18678.0
# 2    3028       660           91687.0
# 3    1243       222           23724.0
# 4     423        72            9459.0

# %%
detail_age_df.iloc[:, 1:11] = detail_age_df.iloc[:, 1:11].div(detail_age_df["Population_total"], axis=0)

# %%
detail_age_df.drop(columns=["Population_total"], inplace=True)
detail_age_df
# Out:
#        county    % lt_10   % 10_19   % 20_29    % 30_39    % 40_49    % 50-59  \
# 0    Anderson  0.0986114  0.112464  0.138999   0.167924    0.15124   0.126028
# 1     Andrews   0.169665  0.162972  0.155905   0.153282   0.111789   0.102366
# 2    Angelina   0.138667  0.145997  0.134065   0.123758   0.119046   0.123365
# 3     Aransas   0.101838   0.10247  0.111533   0.105674  0.0978334   0.130374
# 4      Archer   0.106565  0.124749  0.124326   0.104028   0.115657    0.14621
# ..        ...        ...       ...       ...        ...        ...        ...
# 249      Wood   0.108236  0.112971  0.104168  0.0978771  0.0944537   0.130866
# 250    Yoakum   0.178651  0.167787  0.134633   0.123096   0.101703   0.114023
# 251     Young   0.136209  0.121399  0.109832   0.116156   0.105346   0.125399
# 252    Zapata   0.184873  0.168034   0.13721   0.126151   0.112808  0.0993935
# 253    Zavala   0.177474  0.158702  0.163948   0.114026   0.105337  0.0984507
#
#        % 60_69    % 70_79    % 80_89   % over_90
# 0     0.101392  0.0671934  0.0300955    0.006053
# 1    0.0766142  0.0403148  0.0221651  0.00492558
# 2     0.104519  0.0703589  0.0330254   0.0071984
# 3     0.155792   0.132735  0.0523942  0.00935761
# 4     0.140078  0.0860556  0.0447193   0.0076118
# ..         ...        ...        ...         ...
# 249   0.153229   0.130177  0.0569968   0.0110259
# 250  0.0875896  0.0581317  0.0281138   0.0062724
# 251   0.132858   0.094103  0.0468083   0.0118912
# 252  0.0823403  0.0603639  0.0224046  0.00642169
# 253  0.0898434  0.0575457  0.0271334   0.0075416
#
# [254 rows x 11 columns]

# %%
# dataset originally downloaded from:  https://www.countyhealthrankings.org/app/texas/2020/downloads
in_data_key = "2020 Texas County Health.csv"
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
health_data = pd.read_csv(data_location)
health_data.head()
# Out:
#      county  Life Expectancy  Age-Adjusted Death Rate  \
# 0  Anderson             73.4                    569.0
# 1   Andrews             77.5                    372.0
# 2  Angelina             76.1                    462.0
# 3   Aransas             77.9                    444.0
# 4    Archer             78.8                    384.0
#
#    Motor Vehicle Mortality Rate  % Insufficient Sleep  \
# 0                          20.0                    35
# 1                          39.0                    32
# 2                          19.0                    35
# 3                          20.0                    30
# 4                          29.0                    29
#
#    % Enrolled in Free or Reduced Lunch  Segregation Index  % Homeowners  \
# 0                                 59.0               31.0            71
# 1                                 40.0               10.0            73
# 2                                 67.0               37.0            66
# 3                                 96.0               21.0            78
# 4                                 29.0               27.0            84
#
#    Years of Potential Life Lost Rate  % Fair or Poor Health  % Smokers  \
# 0                            10927.0                     20         17
# 1                             7138.0                     20         13
# 2                             8914.0                     21         16
# 3                             8770.0                     21         14
# 4                             8253.0                     14         14
#
#    % Physically Inactive  % With Access to Exercise Opportunities  \
# 0                     23                                       26
# 1                     26                                       94
# 2                     35                                       65
# 3                     36                                       81
# 4                     19                                       23
#
#    % Flu Vaccinated  High School Graduation Rate  Income inequality  \
# 0              43.0                         97.0                4.3
# 1              24.0                         96.0                4.3
# 2              48.0                         92.0                4.4
# 3              42.0                         89.0                5.3
# 4              46.0                         99.0                4.4
#
#    Social Association Rate  Average Daily PM2.5
# 0                     10.0                  9.9
# 1                      7.3                  7.3
# 2                     11.3                  9.8
# 3                      5.1                  9.3
# 4                      9.1                  8.5

# %%
# merging the second set of datasets together
final2_df = detail_age_df.merge(nh_df, how="left", on="county")
final2_df.head()
# Out:
#      county    % lt_10   % 10_19   % 20_29   % 30_39    % 40_49   % 50-59  \
# 0  Anderson  0.0986114  0.112464  0.138999  0.167924    0.15124  0.126028
# 1   Andrews   0.169665  0.162972  0.155905  0.153282   0.111789  0.102366
# 2  Angelina   0.138667  0.145997  0.134065  0.123758   0.119046  0.123365
# 3   Aransas   0.101838   0.10247  0.111533  0.105674  0.0978334  0.130374
# 4    Archer   0.106565  0.124749  0.124326  0.104028   0.115657   0.14621
#
#      % 60_69    % 70_79    % 80_89   % over_90  nursing home capacity
# 0   0.101392  0.0671934  0.0300955    0.006053                  639.0
# 1  0.0766142  0.0403148  0.0221651  0.00492558                   90.0
# 2   0.104519  0.0703589  0.0330254   0.0071984                  920.0
# 3   0.155792   0.132735  0.0523942  0.00935761                  212.0
# 4   0.140078  0.0860556  0.0447193   0.0076118                   46.0

# %%
final3_df = final2_df.merge(prisons_df, how="left", on="county")
final3_df.head()
# Out:
#      county    % lt_10   % 10_19   % 20_29   % 30_39    % 40_49   % 50-59  \
# 0  Anderson  0.0986114  0.112464  0.138999  0.167924    0.15124  0.126028
# 1   Andrews   0.169665  0.162972  0.155905  0.153282   0.111789  0.102366
# 2  Angelina   0.138667  0.145997  0.134065  0.123758   0.119046  0.123365
# 3   Aransas   0.101838   0.10247  0.111533  0.105674  0.0978334  0.130374
# 4    Archer   0.106565  0.124749  0.124326  0.104028   0.115657   0.14621
#
#      % 60_69    % 70_79    % 80_89   % over_90  nursing home capacity  \
# 0   0.101392  0.0671934  0.0300955    0.006053                  639.0
# 1  0.0766142  0.0403148  0.0221651  0.00492558                   90.0
# 2   0.104519  0.0703589  0.0330254   0.0071984                  920.0
# 3   0.155792   0.132735  0.0523942  0.00935761                  212.0
# 4   0.140078  0.0860556  0.0447193   0.0076118                   46.0
#
#    prison capacity and jail employees
# 0                             17730.0
# 1                                 NaN
# 2                              1399.0
# 3                                 NaN
# 4                                 NaN

# %%
final4_df = final3_df. merge(military, how="left", on="county")
final4_df.head()
# Out:
#      county    % lt_10   % 10_19   % 20_29   % 30_39    % 40_49   % 50-59  \
# 0  Anderson  0.0986114  0.112464  0.138999  0.167924    0.15124  0.126028
# 1   Andrews   0.169665  0.162972  0.155905  0.153282   0.111789  0.102366
# 2  Angelina   0.138667  0.145997  0.134065  0.123758   0.119046  0.123365
# 3   Aransas   0.101838   0.10247  0.111533  0.105674  0.0978334  0.130374
# 4    Archer   0.106565  0.124749  0.124326  0.104028   0.115657   0.14621
#
#      % 60_69    % 70_79    % 80_89   % over_90  nursing home capacity  \
# 0   0.101392  0.0671934  0.0300955    0.006053                  639.0
# 1  0.0766142  0.0403148  0.0221651  0.00492558                   90.0
# 2   0.104519  0.0703589  0.0330254   0.0071984                  920.0
# 3   0.155792   0.132735  0.0523942  0.00935761                  212.0
# 4   0.140078  0.0860556  0.0447193   0.0076118                   46.0
#
#    prison capacity and jail employees  military installation
# 0                             17730.0                    NaN
# 1                                 NaN                    NaN
# 2                              1399.0                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN

# %%
final5_df = final4_df.merge(hos_beds_df, how="left", on='county')
final5_df
# Out:
#        county    % lt_10   % 10_19   % 20_29    % 30_39    % 40_49    % 50-59  \
# 0    Anderson  0.0986114  0.112464  0.138999   0.167924    0.15124   0.126028
# 1     Andrews   0.169665  0.162972  0.155905   0.153282   0.111789   0.102366
# 2    Angelina   0.138667  0.145997  0.134065   0.123758   0.119046   0.123365
# 3     Aransas   0.101838   0.10247  0.111533   0.105674  0.0978334   0.130374
# 4      Archer   0.106565  0.124749  0.124326   0.104028   0.115657    0.14621
# ..        ...        ...       ...       ...        ...        ...        ...
# 249      Wood   0.108236  0.112971  0.104168  0.0978771  0.0944537   0.130866
# 250    Yoakum   0.178651  0.167787  0.134633   0.123096   0.101703   0.114023
# 251     Young   0.136209  0.121399  0.109832   0.116156   0.105346   0.125399
# 252    Zapata   0.184873  0.168034   0.13721   0.126151   0.112808  0.0993935
# 253    Zavala   0.177474  0.158702  0.163948   0.114026   0.105337  0.0984507
#
#        % 60_69    % 70_79    % 80_89   % over_90  nursing home capacity  \
# 0     0.101392  0.0671934  0.0300955    0.006053                  639.0
# 1    0.0766142  0.0403148  0.0221651  0.00492558                   90.0
# 2     0.104519  0.0703589  0.0330254   0.0071984                  920.0
# 3     0.155792   0.132735  0.0523942  0.00935761                  212.0
# 4     0.140078  0.0860556  0.0447193   0.0076118                   46.0
# ..         ...        ...        ...         ...                    ...
# 249   0.153229   0.130177  0.0569968   0.0110259                  615.0
# 250  0.0875896  0.0581317  0.0281138   0.0062724                   60.0
# 251   0.132858   0.094103  0.0468083   0.0118912                  335.0
# 252  0.0823403  0.0603639  0.0224046  0.00642169                   59.0
# 253  0.0898434  0.0575457  0.0271334   0.0075416                    NaN
#
#      prison capacity and jail employees  military installation  hospital beds
# 0                               17730.0                    NaN          156.0
# 1                                   NaN                    NaN           34.0
# 2                                1399.0                    NaN          470.0
# 3                                   NaN                    NaN            NaN
# 4                                   NaN                    NaN            NaN
# ..                                  ...                    ...            ...
# 249                               772.0                    NaN           50.0
# 250                                 NaN                    NaN           24.0
# 251                                 NaN                    NaN           67.0
# 252                                 NaN                    NaN            NaN
# 253                                 NaN                    NaN            NaN
#
# [254 rows x 15 columns]

# %%
final6_df = final5_df.merge(health_data, how="left", on="county")
final6_df
# Out:
#        county    % lt_10   % 10_19   % 20_29    % 30_39    % 40_49    % 50-59  \
# 0    Anderson  0.0986114  0.112464  0.138999   0.167924    0.15124   0.126028
# 1     Andrews   0.169665  0.162972  0.155905   0.153282   0.111789   0.102366
# 2    Angelina   0.138667  0.145997  0.134065   0.123758   0.119046   0.123365
# 3     Aransas   0.101838   0.10247  0.111533   0.105674  0.0978334   0.130374
# 4      Archer   0.106565  0.124749  0.124326   0.104028   0.115657    0.14621
# ..        ...        ...       ...       ...        ...        ...        ...
# 249      Wood   0.108236  0.112971  0.104168  0.0978771  0.0944537   0.130866
# 250    Yoakum   0.178651  0.167787  0.134633   0.123096   0.101703   0.114023
# 251     Young   0.136209  0.121399  0.109832   0.116156   0.105346   0.125399
# 252    Zapata   0.184873  0.168034   0.13721   0.126151   0.112808  0.0993935
# 253    Zavala   0.177474  0.158702  0.163948   0.114026   0.105337  0.0984507
#
#        % 60_69    % 70_79    % 80_89  ... Years of Potential Life Lost Rate  \
# 0     0.101392  0.0671934  0.0300955  ...                           10927.0
# 1    0.0766142  0.0403148  0.0221651  ...                            7138.0
# 2     0.104519  0.0703589  0.0330254  ...                            8914.0
# 3     0.155792   0.132735  0.0523942  ...                            8770.0
# 4     0.140078  0.0860556  0.0447193  ...                            8253.0
# ..         ...        ...        ...  ...                               ...
# 249   0.153229   0.130177  0.0569968  ...                            8653.0
# 250  0.0875896  0.0581317  0.0281138  ...                            7149.0
# 251   0.132858   0.094103  0.0468083  ...                           10209.0
# 252  0.0823403  0.0603639  0.0224046  ...                            7996.0
# 253  0.0898434  0.0575457  0.0271334  ...                            8926.0
#
#      % Fair or Poor Health  % Smokers  % Physically Inactive  \
# 0                       20         17                     23
# 1                       20         13                     26
# 2                       21         16                     35
# 3                       21         14                     36
# 4                       14         14                     19
# ..                     ...        ...                    ...
# 249                     16         14                     32
# 250                     22         14                     28
# 251                     18         16                     29
# 252                     36         17                     20
# 253                     41         20                     20
#
#      % With Access to Exercise Opportunities  % Flu Vaccinated  \
# 0                                         26              43.0
# 1                                         94              24.0
# 2                                         65              48.0
# 3                                         81              42.0
# 4                                         23              46.0
# ..                                       ...               ...
# 249                                       39              40.0
# 250                                       67              17.0
# 251                                       60              38.0
# 252                                       45              32.0
# 253                                       59              26.0
#
#      High School Graduation Rate  Income inequality  Social Association Rate  \
# 0                           97.0                4.3                     10.0
# 1                           96.0                4.3                      7.3
# 2                           92.0                4.4                     11.3
# 3                           89.0                5.3                      5.1
# 4                           99.0                4.4                      9.1
# ..                           ...                ...                      ...
# 249                         95.0                4.6                     14.0
# 250                         98.0                4.8                      8.2
# 251                         97.0                4.2                     12.2
# 252                         90.0                5.4                      2.1
# 253                         92.0                5.1                      3.3
#
#      Average Daily PM2.5
# 0                    9.9
# 1                    7.3
# 2                    9.8
# 3                    9.3
# 4                    8.5
# ..                   ...
# 249                 10.1
# 250                  7.3
# 251                  8.2
# 252                  7.9
# 253                  8.3
#
# [254 rows x 32 columns]

# %%
final6_df.isna().sum()
# Out:
# county                                       0
# % lt_10                                      0
# % 10_19                                      0
# % 20_29                                      0
# % 30_39                                      0
# % 40_49                                      0
# % 50-59                                      0
# % 60_69                                      0
# % 70_79                                      0
# % 80_89                                      0
# % over_90                                    0
# nursing home capacity                       37
# prison capacity and jail employees         196
# military installation                      247
# hospital beds                               69
# Life Expectancy                             17
# Age-Adjusted Death Rate                     10
# Motor Vehicle Mortality Rate                51
# % Insufficient Sleep                         0
# % Enrolled in Free or Reduced Lunch          1
# Segregation Index                           47
# % Homeowners                                 0
# Years of Potential Life Lost Rate           42
# % Fair or Poor Health                        0
# % Smokers                                    0
# % Physically Inactive                        0
# % With Access to Exercise Opportunities      0
# % Flu Vaccinated                             2
# High School Graduation Rate                  2
# Income inequality                            0
# Social Association Rate                      0
# Average Daily PM2.5                          0
# dtype: int64

# %%
# filling in NaNs with 0s for columns where a NaN represents 0 
final6_df.loc[:, ["nursing home capacity", "prison capacity and jail employees", "military installation", "hospital beds" ]] = final6_df.loc[:,["nursing home capacity", "prison capacity and jail employees", "military installation", "hospital beds" ]].fillna(0)

# %%
final6_df.isna().sum()
# Out:
# county                                      0
# % lt_10                                     0
# % 10_19                                     0
# % 20_29                                     0
# % 30_39                                     0
# % 40_49                                     0
# % 50-59                                     0
# % 60_69                                     0
# % 70_79                                     0
# % 80_89                                     0
# % over_90                                   0
# nursing home capacity                       0
# prison capacity and jail employees          0
# military installation                       0
# hospital beds                               0
# Life Expectancy                            17
# Age-Adjusted Death Rate                    10
# Motor Vehicle Mortality Rate               51
# % Insufficient Sleep                        0
# % Enrolled in Free or Reduced Lunch         1
# Segregation Index                          47
# % Homeowners                                0
# Years of Potential Life Lost Rate          42
# % Fair or Poor Health                       0
# % Smokers                                   0
# % Physically Inactive                       0
# % With Access to Exercise Opportunities     0
# % Flu Vaccinated                            2
# High School Graduation Rate                 2
# Income inequality                           0
# Social Association Rate                     0
# Average Daily PM2.5                         0
# dtype: int64

# %%
# filling in the remainder of the NaNs with the median of the column. 
#final6_df.iloc[:, 15:] = final6_df.iloc[:, 15:].apply(lambda col: col.fillna(col.median()), axis=0)

# %%
final6_df.isna().sum()
# Out:
# county                                      0
# % lt_10                                     0
# % 10_19                                     0
# % 20_29                                     0
# % 30_39                                     0
# % 40_49                                     0
# % 50-59                                     0
# % 60_69                                     0
# % 70_79                                     0
# % 80_89                                     0
# % over_90                                   0
# nursing home capacity                       0
# prison capacity and jail employees          0
# military installation                       0
# hospital beds                               0
# Life Expectancy                            17
# Age-Adjusted Death Rate                    10
# Motor Vehicle Mortality Rate               51
# % Insufficient Sleep                        0
# % Enrolled in Free or Reduced Lunch         1
# Segregation Index                          47
# % Homeowners                                0
# Years of Potential Life Lost Rate          42
# % Fair or Poor Health                       0
# % Smokers                                   0
# % Physically Inactive                       0
# % With Access to Exercise Opportunities     0
# % Flu Vaccinated                            2
# High School Graduation Rate                 2
# Income inequality                           0
# Social Association Rate                     0
# Average Daily PM2.5                         0
# dtype: int64

# %%
# removing columns already in dataset
final6_df.drop(columns=["% Fair or Poor Health", "% Smokers", "% Physically Inactive", "Average Daily PM2.5", "Social Association Rate", "High School Graduation Rate"], inplace=True)

# %%
final6_df
# Out:
#        county    % lt_10   % 10_19   % 20_29    % 30_39    % 40_49    % 50-59  \
# 0    Anderson  0.0986114  0.112464  0.138999   0.167924    0.15124   0.126028
# 1     Andrews   0.169665  0.162972  0.155905   0.153282   0.111789   0.102366
# 2    Angelina   0.138667  0.145997  0.134065   0.123758   0.119046   0.123365
# 3     Aransas   0.101838   0.10247  0.111533   0.105674  0.0978334   0.130374
# 4      Archer   0.106565  0.124749  0.124326   0.104028   0.115657    0.14621
# ..        ...        ...       ...       ...        ...        ...        ...
# 249      Wood   0.108236  0.112971  0.104168  0.0978771  0.0944537   0.130866
# 250    Yoakum   0.178651  0.167787  0.134633   0.123096   0.101703   0.114023
# 251     Young   0.136209  0.121399  0.109832   0.116156   0.105346   0.125399
# 252    Zapata   0.184873  0.168034   0.13721   0.126151   0.112808  0.0993935
# 253    Zavala   0.177474  0.158702  0.163948   0.114026   0.105337  0.0984507
#
#        % 60_69    % 70_79    % 80_89  ... Age-Adjusted Death Rate  \
# 0     0.101392  0.0671934  0.0300955  ...                   569.0
# 1    0.0766142  0.0403148  0.0221651  ...                   372.0
# 2     0.104519  0.0703589  0.0330254  ...                   462.0
# 3     0.155792   0.132735  0.0523942  ...                   444.0
# 4     0.140078  0.0860556  0.0447193  ...                   384.0
# ..         ...        ...        ...  ...                     ...
# 249   0.153229   0.130177  0.0569968  ...                   423.0
# 250  0.0875896  0.0581317  0.0281138  ...                   373.0
# 251   0.132858   0.094103  0.0468083  ...                   509.0
# 252  0.0823403  0.0603639  0.0224046  ...                   401.0
# 253  0.0898434  0.0575457  0.0271334  ...                   469.0
#
#      Motor Vehicle Mortality Rate  % Insufficient Sleep  \
# 0                            20.0                    35
# 1                            39.0                    32
# 2                            19.0                    35
# 3                            20.0                    30
# 4                            29.0                    29
# ..                            ...                   ...
# 249                          32.0                    29
# 250                          46.0                    31
# 251                          24.0                    29
# 252                          16.0                    35
# 253                          20.0                    35
#
#      % Enrolled in Free or Reduced Lunch  Segregation Index  % Homeowners  \
# 0                                   59.0               31.0            71
# 1                                   40.0               10.0            73
# 2                                   67.0               37.0            66
# 3                                   96.0               21.0            78
# 4                                   29.0               27.0            84
# ..                                   ...                ...           ...
# 249                                 58.0               44.0            80
# 250                                 56.0               11.0            79
# 251                                 57.0               36.0            78
# 252                                 83.0               12.0            70
# 253                                 80.0               34.0            71
#
#      Years of Potential Life Lost Rate  \
# 0                              10927.0
# 1                               7138.0
# 2                               8914.0
# 3                               8770.0
# 4                               8253.0
# ..                                 ...
# 249                             8653.0
# 250                             7149.0
# 251                            10209.0
# 252                             7996.0
# 253                             8926.0
#
#      % With Access to Exercise Opportunities  % Flu Vaccinated  \
# 0                                         26              43.0
# 1                                         94              24.0
# 2                                         65              48.0
# 3                                         81              42.0
# 4                                         23              46.0
# ..                                       ...               ...
# 249                                       39              40.0
# 250                                       67              17.0
# 251                                       60              38.0
# 252                                       45              32.0
# 253                                       59              26.0
#
#      Income inequality
# 0                  4.3
# 1                  4.3
# 2                  4.4
# 3                  5.3
# 4                  4.4
# ..                 ...
# 249                4.6
# 250                4.8
# 251                4.2
# 252                5.4
# 253                5.1
#
# [254 rows x 26 columns]

# %%
final6_df.head()
# Out:
#      county    % lt_10   % 10_19   % 20_29   % 30_39    % 40_49   % 50-59  \
# 0  Anderson  0.0986114  0.112464  0.138999  0.167924    0.15124  0.126028
# 1   Andrews   0.169665  0.162972  0.155905  0.153282   0.111789  0.102366
# 2  Angelina   0.138667  0.145997  0.134065  0.123758   0.119046  0.123365
# 3   Aransas   0.101838   0.10247  0.111533  0.105674  0.0978334  0.130374
# 4    Archer   0.106565  0.124749  0.124326  0.104028   0.115657   0.14621
#
#      % 60_69    % 70_79    % 80_89  ... Age-Adjusted Death Rate  \
# 0   0.101392  0.0671934  0.0300955  ...                   569.0
# 1  0.0766142  0.0403148  0.0221651  ...                   372.0
# 2   0.104519  0.0703589  0.0330254  ...                   462.0
# 3   0.155792   0.132735  0.0523942  ...                   444.0
# 4   0.140078  0.0860556  0.0447193  ...                   384.0
#
#    Motor Vehicle Mortality Rate  % Insufficient Sleep  \
# 0                          20.0                    35
# 1                          39.0                    32
# 2                          19.0                    35
# 3                          20.0                    30
# 4                          29.0                    29
#
#    % Enrolled in Free or Reduced Lunch  Segregation Index  % Homeowners  \
# 0                                 59.0               31.0            71
# 1                                 40.0               10.0            73
# 2                                 67.0               37.0            66
# 3                                 96.0               21.0            78
# 4                                 29.0               27.0            84
#
#    Years of Potential Life Lost Rate  % With Access to Exercise Opportunities  \
# 0                            10927.0                                       26
# 1                             7138.0                                       94
# 2                             8914.0                                       65
# 3                             8770.0                                       81
# 4                             8253.0                                       23
#
#    % Flu Vaccinated  Income inequality
# 0              43.0                4.3
# 1              24.0                4.3
# 2              48.0                4.4
# 3              42.0                5.3
# 4              46.0                4.4
#
# [5 rows x 26 columns]

# %%
final6_df.to_csv("AJ_secondset.csv", index=False)

# %%
# merging the first and second sets of features together 
all_col_df = final_df_fillna.merge(final6_df, how="left", left_on="County", right_on="county")

# %%
all_col_df.shape
# Out:
# (254, 76)

# %%
all_col_df.columns
# Out:
# Index(['Median Age', '% Age 17 and Under', '% Age 65 and Older',
#        '% Age 85 and Older', '% High School Graduate or Higher',
#        '% Bachelor s Degree or Higher', 'Unemployment Rate (%)',
#        'Ethnicity: % Hispanic', 'Race: % White Alone',
#        'Race: % African American Alone',
#        'Race: % American Indian & Alaska Native Alone', 'Race: % Asian Alone',
#        'Race: % Native Hawaiian and Other Pacific Islander Alone',
#        'Race: % Multi-Racial', 'Votes', 'Percent_Voted', 'Republicans 2016',
#        'Democrats 2016', 'Green 2016', 'Libertarians 2016',
#        'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4', 'Gini.Coefficient',
#        'Management.professional.and.related.occupations',
#        'Service.occupations', 'Sales.and.office.occupations',
#        'Farming.fishing.and.forestry.occupations',
#        'Construction.extraction.maintenance.and.repair.occupations',
#        'Production.transportation.and.material.moving.occupations',
#        'Low.birthweight', 'Teen.births',
#        'Children.in.single.parent.households', 'Adult.obesity', 'Diabetes',
#        'Sexually.transmitted.infections', 'Uninsured', 'Violent.crime',
#        'Injury.deaths', 'CA', 'S', 'MAR', 'CFS', 'ACFS', 'Mean Alc', 'Max Alc',
#        'Mixedness', 'LEN_SEC', 'LN_MILES', 'DVMT', 'DTRKVMT', 'County',
#        'county', '% lt_10', '% 10_19', '% 20_29', '% 30_39', '% 40_49',
#        '% 50-59', '% 60_69', '% 70_79', '% 80_89', '% over_90',
#        'nursing home capacity', 'prison capacity and jail employees',
#        'military installation', 'hospital beds', 'Life Expectancy',
#        'Age-Adjusted Death Rate', 'Motor Vehicle Mortality Rate',
#        '% Insufficient Sleep', '% Enrolled in Free or Reduced Lunch',
#        'Segregation Index', '% Homeowners',
#        'Years of Potential Life Lost Rate',
#        '% With Access to Exercise Opportunities', '% Flu Vaccinated',
#        'Income inequality'],
#       dtype='object')

# %%
# removing redundent columns 
all_col_df.drop(columns=["county", '% Age 17 and Under', '% Age 65 and Older',
       '% Age 85 and Older'], inplace=True)

# %%
in_data_key = 'cleaned_data_1.csv'
data_location = 's3://{}/{}'.format(input_bucket, in_data_key)
all_col_df.to_csv(data_location, index=False)

# %%
df = pd.read_csv(data_location)

# %%
df.head()
# Out:
#    Median Age  % High School Graduate or Higher  \
# 0        39.1                              80.2
# 1        31.8                              73.8
# 2        37.1                              79.9
# 3        49.3                              83.2
# 4        44.3                              90.1
#
#    % Bachelor s Degree or Higher  Unemployment Rate (%)  \
# 0                           11.8                    3.6
# 1                           10.6                    3.1
# 2                           15.7                    5.1
# 3                           20.2                    6.8
# 4                           21.8                    3.4
#
#    Ethnicity: % Hispanic  Race: % White Alone  Race: % African American Alone  \
# 0                  17.82                75.11                           21.49
# 1                  56.19                94.22                            1.94
# 2                  22.18                81.27                           15.44
# 3                  27.66                93.05                            1.79
# 4                   8.68                95.58                            1.03
#
#    Race: % American Indian & Alaska Native Alone  Race: % Asian Alone  \
# 0                                           0.68                 0.90
# 1                                           1.47                 0.75
# 2                                           0.75                 1.17
# 3                                           1.24                 1.93
# 4                                           1.42                 0.43
#
#    Race: % Native Hawaiian and Other Pacific Islander Alone  ...  \
# 0                                               0.14         ...
# 1                                               0.02         ...
# 2                                               0.06         ...
# 3                                               0.08         ...
# 4                                               0.03         ...
#
#    Age-Adjusted Death Rate  Motor Vehicle Mortality Rate  \
# 0                    569.0                          20.0
# 1                    372.0                          39.0
# 2                    462.0                          19.0
# 3                    444.0                          20.0
# 4                    384.0                          29.0
#
#    % Insufficient Sleep  % Enrolled in Free or Reduced Lunch  \
# 0                    35                                 59.0
# 1                    32                                 40.0
# 2                    35                                 67.0
# 3                    30                                 96.0
# 4                    29                                 29.0
#
#    Segregation Index  % Homeowners  Years of Potential Life Lost Rate  \
# 0               31.0            71                            10927.0
# 1               10.0            73                             7138.0
# 2               37.0            66                             8914.0
# 3               21.0            78                             8770.0
# 4               27.0            84                             8253.0
#
#    % With Access to Exercise Opportunities  % Flu Vaccinated  \
# 0                                       26              43.0
# 1                                       94              24.0
# 2                                       65              48.0
# 3                                       81              42.0
# 4                                       23              46.0
#
#    Income inequality
# 0                4.3
# 1                4.3
# 2                4.4
# 3                5.3
# 4                4.4
#
# [5 rows x 72 columns]
